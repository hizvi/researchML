# %%
from process_edus import EDUSample

# %%
set = EDUSample()

# %%
a, b = set.read_labeled(r'../LabeledEDUS_final.txt', z=1)
# Out:
# =====> DATA LOADED

# %%
a
# Out:
# ['particularly funny scene involves 2 itish sister ',
#  "to kick the stupid robber 's ass ! ",
#  'even pro jeff morrow was terrible ! ',
#  'this dvd version features yet more tweaking ',
#  'that you find yourself rooting for the bad guy . ',
#  'horrible sound mixing ',
#  'loosely linking a half a dozen story of the worst kind of depravity ',
#  'laughable and just a bunch of moron ',
#  'you are not so bad after all ',
#  'an auto mechanic falls in love with a beautiful woman , ',
#  '( but surprisingly downbeat ) ',
#  'to end up as one of the worst case of 2 star with non-chemistry on the screen ',
#  "i do subscribe to what one could call the 'message ' of the film - namely art 's essential role in everyday life ",
#  'and found plausible and subtle , ',
#  'and the eventual message of this film makes episode of dragnet look evenhanded by comparison . ',
# ...

# %%
set.nzp
# Out:
# (1742, 1961, 1657)

# %%
b
# Out:
# array([ 1,  0, -1, ...,  1, -1,  1])

# %%
max((map(lambda x: len(x.split()), a)))
# Out:
# 128

# %%
sum(map(lambda x: len(x.split()), a)) / len(a)
# Out:
# 10.386380597014925

# %%
len(a)
# Out:
# 3399
