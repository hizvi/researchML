# %%
from process_edus import EDUSample

# %%
set = EDUSample()

# %%
a, b = set.read_labeled(r'../LabeledEDUS.txt')
# Out:
# =====> DATA LOADED

# %%
a
# Out:
# ["woody 's self-casting - sadly one of the weakest element of his film in recent year - ",
#  'has a great setting ; ',
#  'diana rigg is bad in her role ',
#  'this one is the worst i ',
#  'the supporting cast of worker at the dead letter office are wonderful bit-part in them self , ',
#  'a chimpanzee could come up with much funnier line ',
#  'both young and old that do a fantastic job ',
#  'that i can never experience anything as bad as this again . ',
#  'it was so stupid.but never fear..even ',
#  'and consistently sucked big time with stupidity each and every week . ',
#  'but it had a great plot ',
#  'everyone turns in a decent performance - shashi kapoor ',
#  "( and who seemed to have listened to some bad version of `` apocalypse now '' on some cheap indian drug ) , ",
#  '9/10- 30 minute of pure holiday terror . ',
#  'super speedway makes a great demo of your new dvd / bigscreen / 5.1 channel sound system . ',
#  'one of the first of the best musical ',
# ...

# %%
len(a)
# Out:
# 2564

# %%
b
# Out:
# array([0, 1, 0, ..., 0, 1, 1])
